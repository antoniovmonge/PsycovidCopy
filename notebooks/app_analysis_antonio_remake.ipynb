# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../cleaned_data_040321.csv').drop(columns='Unnamed: 0')

# %%
df.head()
# Out:
#   UserLanguage  Dem_age                  Dem_gender  \
# 0           UR       20                        Male
# 1           IT       68                        Male
# 2          SAR       29  Other/would rather not say
# 3          SAR       38                      Female
# 4          SAR       31                      Female
#
#                                              Dem_edu  \
# 0                   College degree, bachelor, master
# 1                   College degree, bachelor, master
# 2  Some College, short continuing education or eq...
# 3                           Up to 12 years of school
# 4                   College degree, bachelor, master
#
#                   Dem_edu_mom      Dem_employment    Country Dem_Expat  \
# 0                        None             Student   Pakistan       yes
# 1              College degree             Retired      Italy        no
# 2  Some College or equivalent  Part time employed  Argentina        no
# ...

# %%
df[['Country',"PSS10_avg"]]
# Out:
#          Country  PSS10_avg
# 0       Pakistan        2.2
# 1          Italy        2.1
# 2      Argentina        2.3
# 3      Argentina        2.6
# 4      Argentina        2.7
# ...          ...        ...
# 85484    Denmark        1.7
# 85485    Denmark        1.7
# 85486    Denmark        3.0
# 85487    Denmark        1.4
# 85488    Denmark        1.9
#
# [85489 rows x 2 columns]

# %%
plt.hist(df[df['Country']=='Argentina']["PSS10_avg"], density=True, alpha=0.5, label='Argentina')
plt.hist(df[df['Country']=='Pakistan']["PSS10_avg"], density=True, alpha=0.5, label='Pakistan')
plt.xlabel('Perceived Stress', size=10)
plt.ylabel('% of people', size=10)
plt.legend()
